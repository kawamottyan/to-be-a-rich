# %%
#インポート文
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

import lightgbm as lgb
from lightgbm import LGBMRanker

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold

import optuna

# %%
#データのインポート
race_df = pd.read_csv("../data/main/race_data.csv",parse_dates=['datetime'])
horse_df = pd.read_csv("../data/main/horse_data.csv")

# %%
#データのマージ
race_df_for_merge = race_df[['race_id',
                             "race_round",
                             "race_title",
                             "weather",
                             "ground_status",
                             "where_racecourse",
                             "total_horse_number",
                             "frame_number_first",
                             "horse_number_first",
                             "frame_number_second",
                             "horse_number_second",
                             "frame_number_third",
                             "horse_number_third",
                             "tansyo",
                             "hukusyo_first",
                             "hukusyo_second",
                             "hukusyo_third",
                             "wakuren",
                             "umaren",
                             "wide_1_2",
                             "wide_1_3",
                             "wide_2_3",
                             "umatan",
                             "renhuku3",
                             "rentan3",
                             "is_obstacle",
                             "ground_type",
                             "is_left_right_straight",
                             "distance",
                             "weather_rain",
                             "weather_snow",
                             "datetime"
                            ]]

merged_horse_df = pd.merge(horse_df, race_df_for_merge, on='race_id')

# %%
#datetimeをUnix時間に変換してint32に変換する
unix_time = merged_horse_df['datetime'].astype('int64')
unix_time_int32 = unix_time.astype('int32')

merged_horse_df['datetime'] = unix_time_int32

# %%
#エンコード
for column in ['race_title',
               'weather',
               'where_racecourse',
               'ground_type',
               'is_left_right_straight']:
    le = LabelEncoder()
    le.fit(merged_horse_df[column])
    merged_horse_df[column] = le.transform(merged_horse_df[column])

# %%
#使う特徴量の設定
id = {"race_id",
      "horse_id"
    }

feature = [
#horse_df
           "race_id",#後で抜く
           "horse_id",#後で抜く
#            "rank",#目的変数
    
    
           "frame_number",
           "horse_number",
           "sex_and_age",
           "burden_weight",
           "rider_id",
#            "goal_time",結果なので
#            "goal_time_dif",結果なので
#            "half_way_rank",結果なので
#            "last_time",結果なので
#            "odds",
#            "popular",
           "horse_weight",
           "tamer_id",
           "owner_id",
           "is_down",
           "is_senba",
           "is_mesu",
           "is_osu",
           "horse_weight_dif",
           "burden_weight_rate",
#            "avg_velocity",結果なので

#race_df           
             "race_round",
#              "race_title",タイトルはややこしいので
             "weather",
             "ground_status",
             "where_racecourse",
             "total_horse_number",
#              "frame_number_first",結果なので
#              "horse_number_first",
#              "frame_number_second",
#              "horse_number_second",
#              "frame_number_third",
#              "horse_number_third",
#              "tansyo",
#              "hukusyo_first",
#              "hukusyo_second",
#              "hukusyo_third",
#              "wakuren",
#              "umaren",
#              "wide_1_2",
#              "wide_1_3",
#              "wide_2_3",
#              "umatan",
#              "renhuku3",
#              "rentan3",
             "is_obstacle",
             "ground_type",
             "is_left_right_straight",
             "distance",
             "weather_rain",
             "weather_snow",
             "datetime"
            ]

target = ['rank']

X_id = merged_horse_df[feature]
y = merged_horse_df[target]

# %%
#スコア結果を入れるリスト
reports = []
auc_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
support_scores = []

#予測結果を入れるリスト
pred_df_list = []

def objective(trial):
    
# Optuna
    # ハイパーパラメータの探索範囲
    params = {
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 10, 100),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.1, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0),
        'verbose': -1
    }
    
    #LGBMRankerの設定
    ranker = LGBMRanker(**params)

# K-fold
    #kflodの設定
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)

    #kflodで学習用と検証用に分ける
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_id, y)):
        #id入りの学習データ
        X_train_id, X_val_id = X_id.iloc[train_idx], X_id.iloc[val_idx]
        
        #id抜きの学習データ
        X = X_id.drop(id, axis =1)
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        
        #検証データ
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

# Fit
        # train_basketsを計算
        train_baskets = X_train_id.groupby(["race_id"])["horse_id"].count().values

        # モデルの学習
        model = ranker.fit(X_train,
                           y_train,
                           group=train_baskets)

# Predict
        # モデルの予測
        y_pred = model.predict(X_val)

        #結果を入れるデータフレームを用意
        pred_df_fold = pd.DataFrame({
           "race_id": X_val_id['race_id'],
           "horse_id": X_val_id['horse_id'],
           "rank":y_val['rank'],
           "pred": y_pred
           })

        #そのデータフレームをリストに保存
        pred_df_list.append(pred_df_fold)

# Rank
    # 各foldの予測結果を結合してpred_dfを作成
    pred_df = pd.concat(pred_df_list, axis=0).reset_index(drop=True)

    #予測した結果をrace_idごとでグループ化し順位をつける
    pred_df['pred_rank'] = pred_df.groupby('race_id')['pred'].rank(method='min', ascending=False)

    #3位以内ならprizeを1にする
    pred_df['rank_prize'] = pred_df['rank'].apply(lambda x: 1 if x <= 3 else 0)
    pred_df['pred_rank_prize'] = pred_df['pred_rank'].apply(lambda x: 1 if x <= 3 else 0)

#Score
    #正確度を計算
    auc_score = metrics.accuracy_score(pred_df['rank_prize'], pred_df['pred_rank_prize'])
        
    #auc_scoresのリストに保存
    auc_scores.append(auc_score)
    
    #f1を計算            
    f1 = f1_score(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    
    #reportを計算
    report = metrics.classification_report(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    report_num = metrics.precision_recall_fscore_support(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    reports.append(report)

    #reportから情報をとる
    precision_scores.append(report_num[0])
    recall_scores.append(report_num[1])
    f1_scores.append(report_num[2])
    support_scores.append(report_num[3])
    
    return f1

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-03-13 17:28:43,463] A new study created in memory with name: no-name-811063f4-0f8d-4b00-a49e-9a4784a58ac5
# [LightGBM] [Warning] feature_fraction is set=0.7043254308648812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7043254308648812
# [LightGBM] [Warning] lambda_l1 is set=5.228068389122596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.228068389122596
# [LightGBM] [Warning] bagging_fraction is set=0.6757217275906591, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6757217275906591
# [LightGBM] [Warning] lambda_l2 is set=6.80937069570529, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.80937069570529
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.7043254308648812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7043254308648812
# [LightGBM] [Warning] lambda_l1 is set=5.228068389122596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.228068389122596
# [LightGBM] [Warning] bagging_fraction is set=0.6757217275906591, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6757217275906591
# [LightGBM] [Warning] lambda_l2 is set=6.80937069570529, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.80937069570529
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.7043254308648812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7043254308648812
# [LightGBM] [Warning] lambda_l1 is set=5.228068389122596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.228068389122596
# [LightGBM] [Warning] bagging_fraction is set=0.6757217275906591, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6757217275906591
# [LightGBM] [Warning] lambda_l2 is set=6.80937069570529, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.80937069570529
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.7043254308648812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7043254308648812
# [LightGBM] [Warning] lambda_l1 is set=5.228068389122596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.228068389122596
# [LightGBM] [Warning] bagging_fraction is set=0.6757217275906591, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6757217275906591
# [LightGBM] [Warning] lambda_l2 is set=6.80937069570529, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.80937069570529
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.7043254308648812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7043254308648812
# [LightGBM] [Warning] lambda_l1 is set=5.228068389122596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.228068389122596
# [LightGBM] [Warning] bagging_fraction is set=0.6757217275906591, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6757217275906591
# [LightGBM] [Warning] lambda_l2 is set=6.80937069570529, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.80937069570529
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [I 2023-03-13 17:28:44,548] Trial 0 finished with value: 0.16055555555555556 and parameters: {'num_leaves': 92, 'learning_rate': 0.07039620133986378, 'feature_fraction': 0.7043254308648812, 'bagging_fraction': 0.6757217275906591, 'bagging_freq': 6, 'lambda_l1': 5.228068389122596, 'lambda_l2': 6.80937069570529}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.4675249130039866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4675249130039866
# [LightGBM] [Warning] lambda_l1 is set=6.719888700457195, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.719888700457195
# [LightGBM] [Warning] bagging_fraction is set=0.3218874399985643, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3218874399985643
# [LightGBM] [Warning] lambda_l2 is set=8.618922364339044, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.618922364339044
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.4675249130039866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4675249130039866
# [LightGBM] [Warning] lambda_l1 is set=6.719888700457195, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.719888700457195
# [LightGBM] [Warning] bagging_fraction is set=0.3218874399985643, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3218874399985643
# [LightGBM] [Warning] lambda_l2 is set=8.618922364339044, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.618922364339044
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.4675249130039866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4675249130039866
# [LightGBM] [Warning] lambda_l1 is set=6.719888700457195, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.719888700457195
# [LightGBM] [Warning] bagging_fraction is set=0.3218874399985643, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3218874399985643
# [LightGBM] [Warning] lambda_l2 is set=8.618922364339044, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.618922364339044
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.4675249130039866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4675249130039866
# [LightGBM] [Warning] lambda_l1 is set=6.719888700457195, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.719888700457195
# [LightGBM] [Warning] bagging_fraction is set=0.3218874399985643, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3218874399985643
# [LightGBM] [Warning] lambda_l2 is set=8.618922364339044, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.618922364339044
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [I 2023-03-13 17:28:45,180] Trial 1 finished with value: 0.10740740740740741 and parameters: {'num_leaves': 99, 'learning_rate': 0.04606248179866788, 'feature_fraction': 0.4675249130039866, 'bagging_fraction': 0.3218874399985643, 'bagging_freq': 10, 'lambda_l1': 6.719888700457195, 'lambda_l2': 8.618922364339044}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.4675249130039866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4675249130039866
# [LightGBM] [Warning] lambda_l1 is set=6.719888700457195, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.719888700457195
# [LightGBM] [Warning] bagging_fraction is set=0.3218874399985643, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3218874399985643
# [LightGBM] [Warning] lambda_l2 is set=8.618922364339044, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.618922364339044
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.991782211263343, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.991782211263343
# [LightGBM] [Warning] lambda_l1 is set=6.637171407047795, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.637171407047795
# [LightGBM] [Warning] bagging_fraction is set=0.5744358515715108, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5744358515715108
# [LightGBM] [Warning] lambda_l2 is set=0.3141793897065155, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3141793897065155
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.991782211263343, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.991782211263343
# [LightGBM] [Warning] lambda_l1 is set=6.637171407047795, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.637171407047795
# [LightGBM] [Warning] bagging_fraction is set=0.5744358515715108, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5744358515715108
# [LightGBM] [Warning] lambda_l2 is set=0.3141793897065155, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3141793897065155
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.991782211263343, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.991782211263343
# [LightGBM] [Warning] lambda_l1 is set=6.637171407047795, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.637171407047795
# [LightGBM] [Warning] bagging_fraction is set=0.5744358515715108, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5744358515715108
# [LightGBM] [Warning] lambda_l2 is set=0.3141793897065155, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3141793897065155
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.991782211263343, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.991782211263343
# [LightGBM] [Warning] lambda_l1 is set=6.637171407047795, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.637171407047795
# [LightGBM] [Warning] bagging_fraction is set=0.5744358515715108, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5744358515715108
# [LightGBM] [Warning] lambda_l2 is set=0.3141793897065155, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3141793897065155
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.991782211263343, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.991782211263343
# [LightGBM] [Warning] lambda_l1 is set=6.637171407047795, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.637171407047795
# [LightGBM] [Warning] bagging_fraction is set=0.5744358515715108, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5744358515715108
# [LightGBM] [Warning] lambda_l2 is set=0.3141793897065155, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3141793897065155
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2023-03-13 17:28:45,880] Trial 2 finished with value: 0.07694444444444444 and parameters: {'num_leaves': 19, 'learning_rate': 0.06030149660231686, 'feature_fraction': 0.991782211263343, 'bagging_fraction': 0.5744358515715108, 'bagging_freq': 4, 'lambda_l1': 6.637171407047795, 'lambda_l2': 0.3141793897065155}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.9415945324631977, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9415945324631977
# [LightGBM] [Warning] lambda_l1 is set=9.531217844806864, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.531217844806864
# [LightGBM] [Warning] bagging_fraction is set=0.3445316973862834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3445316973862834
# [LightGBM] [Warning] lambda_l2 is set=8.753312900103236, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.753312900103236
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.9415945324631977, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9415945324631977
# [LightGBM] [Warning] lambda_l1 is set=9.531217844806864, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.531217844806864
# [LightGBM] [Warning] bagging_fraction is set=0.3445316973862834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3445316973862834
# [LightGBM] [Warning] lambda_l2 is set=8.753312900103236, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.753312900103236
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.9415945324631977, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9415945324631977
# [LightGBM] [Warning] lambda_l1 is set=9.531217844806864, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.531217844806864
# [LightGBM] [Warning] bagging_fraction is set=0.3445316973862834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3445316973862834
# [LightGBM] [Warning] lambda_l2 is set=8.753312900103236, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.753312900103236
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.9415945324631977, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9415945324631977
# [LightGBM] [Warning] lambda_l1 is set=9.531217844806864, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.531217844806864
# [LightGBM] [Warning] bagging_fraction is set=0.3445316973862834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3445316973862834
# [LightGBM] [Warning] lambda_l2 is set=8.753312900103236, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.753312900103236
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.9415945324631977, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9415945324631977
# [LightGBM] [Warning] lambda_l1 is set=9.531217844806864, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.531217844806864
# [LightGBM] [Warning] bagging_fraction is set=0.3445316973862834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3445316973862834
# [LightGBM] [Warning] lambda_l2 is set=8.753312900103236, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.753312900103236
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2023-03-13 17:28:46,611] Trial 3 finished with value: 0.05888888888888889 and parameters: {'num_leaves': 81, 'learning_rate': 0.08181896921255943, 'feature_fraction': 0.9415945324631977, 'bagging_fraction': 0.3445316973862834, 'bagging_freq': 4, 'lambda_l1': 9.531217844806864, 'lambda_l2': 8.753312900103236}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.35499455578710915, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.35499455578710915
# [LightGBM] [Warning] lambda_l1 is set=9.954756149449153, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.954756149449153
# [LightGBM] [Warning] bagging_fraction is set=0.36363568765976484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36363568765976484
# [LightGBM] [Warning] lambda_l2 is set=9.74263509163345, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.74263509163345
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.35499455578710915, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.35499455578710915
# [LightGBM] [Warning] lambda_l1 is set=9.954756149449153, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.954756149449153
# [LightGBM] [Warning] bagging_fraction is set=0.36363568765976484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36363568765976484
# [LightGBM] [Warning] lambda_l2 is set=9.74263509163345, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.74263509163345
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.35499455578710915, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.35499455578710915
# [LightGBM] [Warning] lambda_l1 is set=9.954756149449153, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.954756149449153
# [LightGBM] [Warning] bagging_fraction is set=0.36363568765976484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36363568765976484
# [LightGBM] [Warning] lambda_l2 is set=9.74263509163345, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.74263509163345
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.35499455578710915, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.35499455578710915
# [LightGBM] [Warning] lambda_l1 is set=9.954756149449153, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.954756149449153
# [LightGBM] [Warning] bagging_fraction is set=0.36363568765976484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36363568765976484
# [LightGBM] [Warning] lambda_l2 is set=9.74263509163345, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.74263509163345
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.35499455578710915, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.35499455578710915
# [LightGBM] [Warning] lambda_l1 is set=9.954756149449153, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.954756149449153
# [LightGBM] [Warning] bagging_fraction is set=0.36363568765976484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36363568765976484
# [LightGBM] [Warning] lambda_l2 is set=9.74263509163345, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.74263509163345
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [I 2023-03-13 17:28:47,378] Trial 4 finished with value: 0.050370370370370364 and parameters: {'num_leaves': 56, 'learning_rate': 0.01889319813070894, 'feature_fraction': 0.35499455578710915, 'bagging_fraction': 0.36363568765976484, 'bagging_freq': 10, 'lambda_l1': 9.954756149449153, 'lambda_l2': 9.74263509163345}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.5990694582484096, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5990694582484096
# [LightGBM] [Warning] lambda_l1 is set=3.111184529936996, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.111184529936996
# [LightGBM] [Warning] bagging_fraction is set=0.5985616886053742, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5985616886053742
# [LightGBM] [Warning] lambda_l2 is set=8.63575440501804, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.63575440501804
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.5990694582484096, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5990694582484096
# [LightGBM] [Warning] lambda_l1 is set=3.111184529936996, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.111184529936996
# [LightGBM] [Warning] bagging_fraction is set=0.5985616886053742, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5985616886053742
# [LightGBM] [Warning] lambda_l2 is set=8.63575440501804, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.63575440501804
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.5990694582484096, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5990694582484096
# [LightGBM] [Warning] lambda_l1 is set=3.111184529936996, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.111184529936996
# [LightGBM] [Warning] bagging_fraction is set=0.5985616886053742, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5985616886053742
# [LightGBM] [Warning] lambda_l2 is set=8.63575440501804, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.63575440501804
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.5990694582484096, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5990694582484096
# [LightGBM] [Warning] lambda_l1 is set=3.111184529936996, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.111184529936996
# [LightGBM] [Warning] bagging_fraction is set=0.5985616886053742, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5985616886053742
# [LightGBM] [Warning] lambda_l2 is set=8.63575440501804, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.63575440501804
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.5990694582484096, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5990694582484096
# [LightGBM] [Warning] lambda_l1 is set=3.111184529936996, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.111184529936996
# [LightGBM] [Warning] bagging_fraction is set=0.5985616886053742, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5985616886053742
# [LightGBM] [Warning] lambda_l2 is set=8.63575440501804, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.63575440501804
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2023-03-13 17:28:48,664] Trial 5 finished with value: 0.04380952380952381 and parameters: {'num_leaves': 87, 'learning_rate': 0.014248826390472966, 'feature_fraction': 0.5990694582484096, 'bagging_fraction': 0.5985616886053742, 'bagging_freq': 4, 'lambda_l1': 3.111184529936996, 'lambda_l2': 8.63575440501804}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.6871532801393894, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6871532801393894
# [LightGBM] [Warning] lambda_l1 is set=0.4521705573942416, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4521705573942416
# [LightGBM] [Warning] bagging_fraction is set=0.5180442655259928, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5180442655259928
# [LightGBM] [Warning] lambda_l2 is set=4.252090443781202, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.252090443781202
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.6871532801393894, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6871532801393894
# [LightGBM] [Warning] lambda_l1 is set=0.4521705573942416, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4521705573942416
# [LightGBM] [Warning] bagging_fraction is set=0.5180442655259928, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5180442655259928
# [LightGBM] [Warning] lambda_l2 is set=4.252090443781202, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.252090443781202
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.6871532801393894, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6871532801393894
# [LightGBM] [Warning] lambda_l1 is set=0.4521705573942416, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4521705573942416
# [LightGBM] [Warning] bagging_fraction is set=0.5180442655259928, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5180442655259928
# [LightGBM] [Warning] lambda_l2 is set=4.252090443781202, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.252090443781202
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.6871532801393894, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6871532801393894
# [LightGBM] [Warning] lambda_l1 is set=0.4521705573942416, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4521705573942416
# [LightGBM] [Warning] bagging_fraction is set=0.5180442655259928, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5180442655259928
# [LightGBM] [Warning] lambda_l2 is set=4.252090443781202, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.252090443781202
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.6871532801393894, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6871532801393894
# [LightGBM] [Warning] lambda_l1 is set=0.4521705573942416, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4521705573942416
# [LightGBM] [Warning] bagging_fraction is set=0.5180442655259928, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5180442655259928
# [LightGBM] [Warning] lambda_l2 is set=4.252090443781202, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.252090443781202
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2023-03-13 17:28:50,114] Trial 6 finished with value: 0.03722222222222222 and parameters: {'num_leaves': 93, 'learning_rate': 0.004961825705177959, 'feature_fraction': 0.6871532801393894, 'bagging_fraction': 0.5180442655259928, 'bagging_freq': 4, 'lambda_l1': 0.4521705573942416, 'lambda_l2': 4.252090443781202}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.4693593616770828, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4693593616770828
# [LightGBM] [Warning] lambda_l1 is set=3.629963517747032, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.629963517747032
# [LightGBM] [Warning] bagging_fraction is set=0.9465966512637679, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9465966512637679
# [LightGBM] [Warning] lambda_l2 is set=5.065225443400262, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.065225443400262
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4693593616770828, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4693593616770828
# [LightGBM] [Warning] lambda_l1 is set=3.629963517747032, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.629963517747032
# [LightGBM] [Warning] bagging_fraction is set=0.9465966512637679, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9465966512637679
# [LightGBM] [Warning] lambda_l2 is set=5.065225443400262, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.065225443400262
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4693593616770828, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4693593616770828
# [LightGBM] [Warning] lambda_l1 is set=3.629963517747032, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.629963517747032
# [LightGBM] [Warning] bagging_fraction is set=0.9465966512637679, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9465966512637679
# [LightGBM] [Warning] lambda_l2 is set=5.065225443400262, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.065225443400262
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4693593616770828, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4693593616770828
# [LightGBM] [Warning] lambda_l1 is set=3.629963517747032, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.629963517747032
# [LightGBM] [Warning] bagging_fraction is set=0.9465966512637679, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9465966512637679
# [LightGBM] [Warning] lambda_l2 is set=5.065225443400262, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.065225443400262
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4693593616770828, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4693593616770828
# [LightGBM] [Warning] lambda_l1 is set=3.629963517747032, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.629963517747032
# [LightGBM] [Warning] bagging_fraction is set=0.9465966512637679, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9465966512637679
# [LightGBM] [Warning] lambda_l2 is set=5.065225443400262, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.065225443400262
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2023-03-13 17:28:51,092] Trial 7 finished with value: 0.03222222222222222 and parameters: {'num_leaves': 35, 'learning_rate': 0.024014931953323337, 'feature_fraction': 0.4693593616770828, 'bagging_fraction': 0.9465966512637679, 'bagging_freq': 2, 'lambda_l1': 3.629963517747032, 'lambda_l2': 5.065225443400262}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.7051445525445197, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7051445525445197
# [LightGBM] [Warning] lambda_l1 is set=6.032215491246884, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.032215491246884
# [LightGBM] [Warning] bagging_fraction is set=0.2946298729961914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2946298729961914
# [LightGBM] [Warning] lambda_l2 is set=7.52233202098455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.52233202098455
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.7051445525445197, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7051445525445197
# [LightGBM] [Warning] lambda_l1 is set=6.032215491246884, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.032215491246884
# [LightGBM] [Warning] bagging_fraction is set=0.2946298729961914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2946298729961914
# [LightGBM] [Warning] lambda_l2 is set=7.52233202098455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.52233202098455
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.7051445525445197, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7051445525445197
# [LightGBM] [Warning] lambda_l1 is set=6.032215491246884, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.032215491246884
# [LightGBM] [Warning] bagging_fraction is set=0.2946298729961914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2946298729961914
# [LightGBM] [Warning] lambda_l2 is set=7.52233202098455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.52233202098455
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.7051445525445197, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7051445525445197
# [LightGBM] [Warning] lambda_l1 is set=6.032215491246884, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.032215491246884
# [LightGBM] [Warning] bagging_fraction is set=0.2946298729961914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2946298729961914
# [LightGBM] [Warning] lambda_l2 is set=7.52233202098455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.52233202098455
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.7051445525445197, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7051445525445197
# [LightGBM] [Warning] lambda_l1 is set=6.032215491246884, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.032215491246884
# [LightGBM] [Warning] bagging_fraction is set=0.2946298729961914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2946298729961914
# [LightGBM] [Warning] lambda_l2 is set=7.52233202098455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.52233202098455
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [I 2023-03-13 17:28:51,937] Trial 8 finished with value: 0.02855555555555555 and parameters: {'num_leaves': 93, 'learning_rate': 0.0621320577505747, 'feature_fraction': 0.7051445525445197, 'bagging_fraction': 0.2946298729961914, 'bagging_freq': 8, 'lambda_l1': 6.032215491246884, 'lambda_l2': 7.52233202098455}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.686717496501801, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.686717496501801
# [LightGBM] [Warning] lambda_l1 is set=2.8056411996984187, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8056411996984187
# [LightGBM] [Warning] bagging_fraction is set=0.3611193043766956, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3611193043766956
# [LightGBM] [Warning] lambda_l2 is set=6.706522769080298, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.706522769080298
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.686717496501801, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.686717496501801
# [LightGBM] [Warning] lambda_l1 is set=2.8056411996984187, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8056411996984187
# [LightGBM] [Warning] bagging_fraction is set=0.3611193043766956, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3611193043766956
# [LightGBM] [Warning] lambda_l2 is set=6.706522769080298, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.706522769080298
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.686717496501801, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.686717496501801
# [LightGBM] [Warning] lambda_l1 is set=2.8056411996984187, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8056411996984187
# [LightGBM] [Warning] bagging_fraction is set=0.3611193043766956, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3611193043766956
# [LightGBM] [Warning] lambda_l2 is set=6.706522769080298, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.706522769080298
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.686717496501801, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.686717496501801
# [LightGBM] [Warning] lambda_l1 is set=2.8056411996984187, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8056411996984187
# [LightGBM] [Warning] bagging_fraction is set=0.3611193043766956, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3611193043766956
# [LightGBM] [Warning] lambda_l2 is set=6.706522769080298, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.706522769080298
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.686717496501801, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.686717496501801
# [LightGBM] [Warning] lambda_l1 is set=2.8056411996984187, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8056411996984187
# [LightGBM] [Warning] bagging_fraction is set=0.3611193043766956, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3611193043766956
# [LightGBM] [Warning] lambda_l2 is set=6.706522769080298, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.706522769080298
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [I 2023-03-13 17:28:53,055] Trial 9 finished with value: 0.025858585858585862 and parameters: {'num_leaves': 66, 'learning_rate': 0.03455546620398547, 'feature_fraction': 0.686717496501801, 'bagging_fraction': 0.3611193043766956, 'bagging_freq': 5, 'lambda_l1': 2.8056411996984187, 'lambda_l2': 6.706522769080298}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.10998920921723498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10998920921723498
# [LightGBM] [Warning] lambda_l1 is set=7.61376569634557, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.61376569634557
# [LightGBM] [Warning] bagging_fraction is set=0.821911985545911, subsample=1.0 will be ignored. Current value: bagging_fraction=0.821911985545911
# [LightGBM] [Warning] lambda_l2 is set=5.492246952045168, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.492246952045168
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.10998920921723498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10998920921723498
# [LightGBM] [Warning] lambda_l1 is set=7.61376569634557, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.61376569634557
# [LightGBM] [Warning] bagging_fraction is set=0.821911985545911, subsample=1.0 will be ignored. Current value: bagging_fraction=0.821911985545911
# [LightGBM] [Warning] lambda_l2 is set=5.492246952045168, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.492246952045168
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.10998920921723498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10998920921723498
# [LightGBM] [Warning] lambda_l1 is set=7.61376569634557, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.61376569634557
# [LightGBM] [Warning] bagging_fraction is set=0.821911985545911, subsample=1.0 will be ignored. Current value: bagging_fraction=0.821911985545911
# [LightGBM] [Warning] lambda_l2 is set=5.492246952045168, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.492246952045168
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.10998920921723498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10998920921723498
# [LightGBM] [Warning] lambda_l1 is set=7.61376569634557, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.61376569634557
# [LightGBM] [Warning] bagging_fraction is set=0.821911985545911, subsample=1.0 will be ignored. Current value: bagging_fraction=0.821911985545911
# [LightGBM] [Warning] lambda_l2 is set=5.492246952045168, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.492246952045168
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.10998920921723498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10998920921723498
# [LightGBM] [Warning] lambda_l1 is set=7.61376569634557, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.61376569634557
# [LightGBM] [Warning] bagging_fraction is set=0.821911985545911, subsample=1.0 will be ignored. Current value: bagging_fraction=0.821911985545911
# [LightGBM] [Warning] lambda_l2 is set=5.492246952045168, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.492246952045168
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [I 2023-03-13 17:28:53,876] Trial 10 finished with value: 0.02351851851851852 and parameters: {'num_leaves': 69, 'learning_rate': 0.09923924216119231, 'feature_fraction': 0.10998920921723498, 'bagging_fraction': 0.821911985545911, 'bagging_freq': 7, 'lambda_l1': 7.61376569634557, 'lambda_l2': 5.492246952045168}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.43038830055522675, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.43038830055522675
# [LightGBM] [Warning] lambda_l1 is set=5.22739132843059, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.22739132843059
# [LightGBM] [Warning] bagging_fraction is set=0.1641740101428896, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1641740101428896
# [LightGBM] [Warning] lambda_l2 is set=7.402815985019312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.402815985019312
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.43038830055522675, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.43038830055522675
# [LightGBM] [Warning] lambda_l1 is set=5.22739132843059, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.22739132843059
# [LightGBM] [Warning] bagging_fraction is set=0.1641740101428896, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1641740101428896
# [LightGBM] [Warning] lambda_l2 is set=7.402815985019312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.402815985019312
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.43038830055522675, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.43038830055522675
# [LightGBM] [Warning] lambda_l1 is set=5.22739132843059, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.22739132843059
# [LightGBM] [Warning] bagging_fraction is set=0.1641740101428896, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1641740101428896
# [LightGBM] [Warning] lambda_l2 is set=7.402815985019312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.402815985019312
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.43038830055522675, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.43038830055522675
# [LightGBM] [Warning] lambda_l1 is set=5.22739132843059, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.22739132843059
# [LightGBM] [Warning] bagging_fraction is set=0.1641740101428896, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1641740101428896
# [LightGBM] [Warning] lambda_l2 is set=7.402815985019312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.402815985019312
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.43038830055522675, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.43038830055522675
# [LightGBM] [Warning] lambda_l1 is set=5.22739132843059, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.22739132843059
# [LightGBM] [Warning] bagging_fraction is set=0.1641740101428896, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1641740101428896
# [LightGBM] [Warning] lambda_l2 is set=7.402815985019312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.402815985019312
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [I 2023-03-13 17:28:54,605] Trial 11 finished with value: 0.020854700854700852 and parameters: {'num_leaves': 80, 'learning_rate': 0.046536185916944, 'feature_fraction': 0.43038830055522675, 'bagging_fraction': 0.1641740101428896, 'bagging_freq': 10, 'lambda_l1': 5.22739132843059, 'lambda_l2': 7.402815985019312}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.8300345962664639, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8300345962664639
# [LightGBM] [Warning] lambda_l1 is set=7.807303937806677, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.807303937806677
# [LightGBM] [Warning] bagging_fraction is set=0.72585045465804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.72585045465804
# [LightGBM] [Warning] lambda_l2 is set=9.070214461822154, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.070214461822154
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.8300345962664639, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8300345962664639
# [LightGBM] [Warning] lambda_l1 is set=7.807303937806677, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.807303937806677
# [LightGBM] [Warning] bagging_fraction is set=0.72585045465804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.72585045465804
# [LightGBM] [Warning] lambda_l2 is set=9.070214461822154, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.070214461822154
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.8300345962664639, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8300345962664639
# [LightGBM] [Warning] lambda_l1 is set=7.807303937806677, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.807303937806677
# [LightGBM] [Warning] bagging_fraction is set=0.72585045465804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.72585045465804
# [LightGBM] [Warning] lambda_l2 is set=9.070214461822154, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.070214461822154
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.8300345962664639, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8300345962664639
# [LightGBM] [Warning] lambda_l1 is set=7.807303937806677, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.807303937806677
# [LightGBM] [Warning] bagging_fraction is set=0.72585045465804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.72585045465804
# [LightGBM] [Warning] lambda_l2 is set=9.070214461822154, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.070214461822154
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.8300345962664639, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8300345962664639
# [LightGBM] [Warning] lambda_l1 is set=7.807303937806677, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.807303937806677
# [LightGBM] [Warning] bagging_fraction is set=0.72585045465804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.72585045465804
# ...
# [LightGBM] [Warning] lambda_l2 is set=0.39719817095592536, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.39719817095592536
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8990918804326286, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8990918804326286
# [LightGBM] [Warning] lambda_l1 is set=5.601007382277169, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.601007382277169
# [LightGBM] [Warning] bagging_fraction is set=0.6181991365241841, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6181991365241841
# [LightGBM] [Warning] lambda_l2 is set=0.39719817095592536, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.39719817095592536
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [I 2023-03-13 17:29:08,165] Trial 22 finished with value: 0.010925925925925926 and parameters: {'num_leaves': 28, 'learning_rate': 0.06534708858050499, 'feature_fraction': 0.8990918804326286, 'bagging_fraction': 0.6181991365241841, 'bagging_freq': 5, 'lambda_l1': 5.601007382277169, 'lambda_l2': 0.39719817095592536}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.8918500887582161, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8918500887582161
# [LightGBM] [Warning] lambda_l1 is set=6.520790353124092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.520790353124092
# [LightGBM] [Warning] bagging_fraction is set=0.43157739477489376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43157739477489376
# [LightGBM] [Warning] lambda_l2 is set=2.2184519977742765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2184519977742765
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.8918500887582161, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8918500887582161
# [LightGBM] [Warning] lambda_l1 is set=6.520790353124092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.520790353124092
# [LightGBM] [Warning] bagging_fraction is set=0.43157739477489376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43157739477489376
# [LightGBM] [Warning] lambda_l2 is set=2.2184519977742765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2184519977742765
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.8918500887582161, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8918500887582161
# [LightGBM] [Warning] lambda_l1 is set=6.520790353124092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.520790353124092
# [LightGBM] [Warning] bagging_fraction is set=0.43157739477489376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43157739477489376
# [LightGBM] [Warning] lambda_l2 is set=2.2184519977742765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2184519977742765
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.8918500887582161, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8918500887582161
# [LightGBM] [Warning] lambda_l1 is set=6.520790353124092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.520790353124092
# [LightGBM] [Warning] bagging_fraction is set=0.43157739477489376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43157739477489376
# [LightGBM] [Warning] lambda_l2 is set=2.2184519977742765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2184519977742765
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.8918500887582161, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8918500887582161
# [LightGBM] [Warning] lambda_l1 is set=6.520790353124092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.520790353124092
# [LightGBM] [Warning] bagging_fraction is set=0.43157739477489376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43157739477489376
# [LightGBM] [Warning] lambda_l2 is set=2.2184519977742765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2184519977742765
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2023-03-13 17:29:09,288] Trial 23 finished with value: 0.010577777777777776 and parameters: {'num_leaves': 19, 'learning_rate': 0.05396395646820017, 'feature_fraction': 0.8918500887582161, 'bagging_fraction': 0.43157739477489376, 'bagging_freq': 3, 'lambda_l1': 6.520790353124092, 'lambda_l2': 2.2184519977742765}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.9288994608398673, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9288994608398673
# [LightGBM] [Warning] lambda_l1 is set=5.310143033358065, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.310143033358065
# [LightGBM] [Warning] bagging_fraction is set=0.5128183022721868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5128183022721868
# [LightGBM] [Warning] lambda_l2 is set=3.992600142243764, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.992600142243764
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.9288994608398673, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9288994608398673
# [LightGBM] [Warning] lambda_l1 is set=5.310143033358065, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.310143033358065
# [LightGBM] [Warning] bagging_fraction is set=0.5128183022721868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5128183022721868
# [LightGBM] [Warning] lambda_l2 is set=3.992600142243764, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.992600142243764
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.9288994608398673, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9288994608398673
# [LightGBM] [Warning] lambda_l1 is set=5.310143033358065, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.310143033358065
# [LightGBM] [Warning] bagging_fraction is set=0.5128183022721868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5128183022721868
# [LightGBM] [Warning] lambda_l2 is set=3.992600142243764, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.992600142243764
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.9288994608398673, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9288994608398673
# [LightGBM] [Warning] lambda_l1 is set=5.310143033358065, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.310143033358065
# [LightGBM] [Warning] bagging_fraction is set=0.5128183022721868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5128183022721868
# [LightGBM] [Warning] lambda_l2 is set=3.992600142243764, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.992600142243764
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.9288994608398673, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9288994608398673
# [LightGBM] [Warning] lambda_l1 is set=5.310143033358065, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.310143033358065
# [LightGBM] [Warning] bagging_fraction is set=0.5128183022721868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5128183022721868
# [LightGBM] [Warning] lambda_l2 is set=3.992600142243764, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.992600142243764
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [I 2023-03-13 17:29:10,802] Trial 24 finished with value: 0.010085470085470087 and parameters: {'num_leaves': 44, 'learning_rate': 0.043501560039108225, 'feature_fraction': 0.9288994608398673, 'bagging_fraction': 0.5128183022721868, 'bagging_freq': 6, 'lambda_l1': 5.310143033358065, 'lambda_l2': 3.992600142243764}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.9979828320469294, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9979828320469294
# [LightGBM] [Warning] lambda_l1 is set=7.2073417439239496, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2073417439239496
# [LightGBM] [Warning] bagging_fraction is set=0.7071631786503675, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7071631786503675
# [LightGBM] [Warning] lambda_l2 is set=1.8793110935835653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8793110935835653
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.9979828320469294, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9979828320469294
# [LightGBM] [Warning] lambda_l1 is set=7.2073417439239496, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2073417439239496
# [LightGBM] [Warning] bagging_fraction is set=0.7071631786503675, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7071631786503675
# [LightGBM] [Warning] lambda_l2 is set=1.8793110935835653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8793110935835653
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.9979828320469294, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9979828320469294
# [LightGBM] [Warning] lambda_l1 is set=7.2073417439239496, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2073417439239496
# [LightGBM] [Warning] bagging_fraction is set=0.7071631786503675, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7071631786503675
# [LightGBM] [Warning] lambda_l2 is set=1.8793110935835653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8793110935835653
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.9979828320469294, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9979828320469294
# [LightGBM] [Warning] lambda_l1 is set=7.2073417439239496, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2073417439239496
# [LightGBM] [Warning] bagging_fraction is set=0.7071631786503675, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7071631786503675
# [LightGBM] [Warning] lambda_l2 is set=1.8793110935835653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8793110935835653
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.9979828320469294, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9979828320469294
# [LightGBM] [Warning] lambda_l1 is set=7.2073417439239496, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2073417439239496
# [LightGBM] [Warning] bagging_fraction is set=0.7071631786503675, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7071631786503675
# [LightGBM] [Warning] lambda_l2 is set=1.8793110935835653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8793110935835653
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [I 2023-03-13 17:29:12,393] Trial 25 finished with value: 0.009794238683127572 and parameters: {'num_leaves': 92, 'learning_rate': 0.07186961200234197, 'feature_fraction': 0.9979828320469294, 'bagging_fraction': 0.7071631786503675, 'bagging_freq': 7, 'lambda_l1': 7.2073417439239496, 'lambda_l2': 1.8793110935835653}. Best is trial 0 with value: 0.16055555555555556.
# [LightGBM] [Warning] feature_fraction is set=0.760991951024554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.760991951024554
# [LightGBM] [Warning] lambda_l1 is set=6.090099645516904, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.090099645516904
# [LightGBM] [Warning] bagging_fraction is set=0.11074820604600888, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11074820604600888
# [LightGBM] [Warning] lambda_l2 is set=3.0746287522066247, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0746287522066247
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.760991951024554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.760991951024554
# [LightGBM] [Warning] lambda_l1 is set=6.090099645516904, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.090099645516904
# [LightGBM] [Warning] bagging_fraction is set=0.11074820604600888, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11074820604600888
# [LightGBM] [Warning] lambda_l2 is set=3.0746287522066247, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0746287522066247
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.760991951024554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.760991951024554
# [LightGBM] [Warning] lambda_l1 is set=6.090099645516904, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.090099645516904
# [LightGBM] [Warning] bagging_fraction is set=0.11074820604600888, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11074820604600888
# [LightGBM] [Warning] lambda_l2 is set=3.0746287522066247, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0746287522066247
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.760991951024554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.760991951024554
# [LightGBM] [Warning] lambda_l1 is set=6.090099645516904, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.090099645516904
# [LightGBM] [Warning] bagging_fraction is set=0.11074820604600888, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11074820604600888
# [LightGBM] [Warning] lambda_l2 is set=3.0746287522066247, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0746287522066247
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.760991951024554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.760991951024554
# [LightGBM] [Warning] lambda_l1 is set=6.090099645516904, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.090099645516904
# [LightGBM] [Warning] bagging_fraction is set=0.11074820604600888, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11074820604600888
# [LightGBM] [Warning] lambda_l2 is set=3.0746287522066247, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0746287522066247
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3

# %%
study.trials_dataframe()

# %%
#各ランダムステートの正確度平均と標準偏差を出力
avg_auc_score = np.mean(auc_scores, axis=0)
std_score = np.std(auc_scores, axis=0)

# 平均と重み付き平均を計算する
precision_avg = np.mean(precision_scores, axis=0)
recall_avg = np.mean(recall_scores, axis=0)
f1_avg = np.mean(f1_scores, axis=0)
support_sum = np.sum(support_scores, axis=0)

# precision_weighted = np.average(precision_avg, weights=support_sum)
# recall_weighted = np.average(recall_avg, weights=support_sum)
# f1_weighted = np.average(f1_avg, weights=support_sum)

# %%
print(f"Std: {std_score:.4f}")
print(f"Average AUC score: {avg_auc_score:.4f}")
print(f"Average PRE score 0: {precision_avg[0]:.4f}"+f"   1: {precision_avg[1]:.4f}")
print(f"Average REC score 0: {recall_avg[0]:.4f}"+f"   1: {recall_avg[1]:.4f}")
print(f"Average F1  score 0: {f1_avg[0]:.4f}"+f"   1: {f1_avg[1]:.4f}")

# %%
print(reports[0])

# %%
print(reports[1])

# %%
print(reports[2])

# %%
print(reports[3])

# %%
print(reports[4])

# %%
#Optunaによる、ベストパラメータの取得
best_params = study.best_params

# %%
#結果を入れるリスト
reports = []
auc_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
support_scores = []

#ランダムステートを変更し、kfoldを繰り返す
for random_state in range(5):
    
    #予測結果を入れるリスト
    pred_df_list = []
    
    #kflodの設定
    kfold = KFold(n_splits=5, shuffle=True, random_state=random_state)
    
    #kflodで学習用と検証用に分ける
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_id, y)):
        X_train_id, X_val_id = X_id.iloc[train_idx], X_id.iloc[val_idx]
        
        X = X_id.drop(id, axis =1)
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # ここでtrain_basketsを計算する
        train_baskets = X_train_id.groupby(["race_id"])["horse_id"].count().values
        
        best_ranker = LGBMRanker(**best_params)

        # モデルの学習
        model = best_ranker.fit(X_train,
                           y_train,
                           group=train_baskets)

        # モデルの予測
        y_pred = model.predict(X_val)

        #結果を入れるデータフレームを用意
        pred_df_fold = pd.DataFrame({
           "race_id": X_val_id['race_id'],
           "horse_id": X_val_id['horse_id'],
           "rank":y_val['rank'],
           "pred": y_pred
           })
        
        #そのデータフレームをリストに保存
        pred_df_list.append(pred_df_fold)

    # 各foldの予測結果を結合してpred_dfを作成
    pred_df = pd.concat(pred_df_list, axis=0).reset_index(drop=True)
    
    #予測した結果をrace_idごとでグループ化し順位をつける
    pred_df['pred_rank'] = pred_df.groupby('race_id')['pred'].rank(method='min', ascending=False)
    
    #3位以内ならprizeを1にする
    pred_df['rank_prize'] = pred_df['rank'].apply(lambda x: 1 if x <= 3 else 0)
    pred_df['pred_rank_prize'] = pred_df['pred_rank'].apply(lambda x: 1 if x <= 3 else 0)
    
    #正確度を計算
    auc_score = metrics.accuracy_score(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    report = metrics.classification_report(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    report_num = metrics.precision_recall_fscore_support(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    #auc_scoresのリストに保存
    auc_scores.append(auc_score)
    
    reports.append(report)
    
    precision_scores.append(report_num[0])
    recall_scores.append(report_num[1])
    f1_scores.append(report_num[2])
    support_scores.append(report_num[3])
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9507627338684779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9507627338684779
# [LightGBM] [Warning] lambda_l1 is set=9.304071437426181, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.304071437426181
# [LightGBM] [Warning] bagging_fraction is set=0.11136932833333091, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11136932833333091
# [LightGBM] [Warning] lambda_l2 is set=7.477357868187411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.477357868187411
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9

# %%
#各ランダムステートの正確度平均と標準偏差を出力
avg_auc_score = np.mean(auc_scores, axis=0)
std_score = np.std(auc_scores, axis=0)

# 平均と重み付き平均を計算する
precision_avg = np.mean(precision_scores, axis=0)
recall_avg = np.mean(recall_scores, axis=0)
f1_avg = np.mean(f1_scores, axis=0)
support_sum = np.sum(support_scores, axis=0)

# %%
print(f"Std: {std_score:.4f}")
print(f"Average AUC score: {avg_auc_score:.4f}")
print(f"Average PRE score 0: {precision_avg[0]:.4f}"+f"   1: {precision_avg[1]:.4f}")
print(f"Average REC score 0: {recall_avg[0]:.4f}"+f"   1: {recall_avg[1]:.4f}")
print(f"Average F1  score 0: {f1_avg[0]:.4f}"+f"   1: {f1_avg[1]:.4f}")
# Out:
# Std: 0.0034
# Average AUC score: 0.6517
# Average PRE score 0: 0.7786   1: 0.1838
# Average REC score 0: 0.7786   1: 0.1838
# Average F1  score 0: 0.7786   1: 0.1838

# %%
print(reports[0])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78      6637
#            1       0.19      0.19      0.19      1800
#
#     accuracy                           0.65      8437
#    macro avg       0.48      0.48      0.48      8437
# weighted avg       0.65      0.65      0.65      8437

# %%
#特徴量の重要度
for i in model.feature_importances_.argsort()[::-1]:
    print(feature[i], model.feature_importances_[i]/model.feature_importances_.sum())
# Out:
# horse_weight 0.125
# rider_id 0.11529126213592233
# weather_rain 0.10436893203883495
# sex_and_age 0.10194174757281553
# burden_weight 0.07524271844660194
# is_osu 0.07160194174757281
# horse_id 0.06553398058252427
# is_mesu 0.06553398058252427
# ground_status 0.06067961165048544
# horse_weight_dif 0.03519417475728155
# race_id 0.032766990291262135
# horse_number 0.03033980582524272
# ground_type 0.025485436893203883
# burden_weight_rate 0.02063106796116505
# frame_number 0.01820388349514563
# weather 0.01820388349514563
# is_down 0.00849514563106796
# total_horse_number 0.007281553398058253
# is_senba 0.007281553398058253
# race_round 0.006067961165048544
# is_obstacle 0.0036407766990291263
# owner_id 0.0012135922330097086
# where_racecourse 0.0
# distance 0.0
# is_left_right_straight 0.0
# tamer_id 0.0
