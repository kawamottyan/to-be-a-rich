# %%
#インポート文
import numpy as np
import pandas as pd

import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

import lightgbm as lgb
from lightgbm import LGBMRanker

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold

from sklearn.metrics import confusion_matrix

import optuna

# %%
#データのインポート
race_df = pd.read_csv("../data/main/race_data.csv",parse_dates=['datetime'])
horse_df = pd.read_csv("../data/main/horse_data.csv")

# %%
#データのマージ
race_df_for_merge = race_df[['race_id',
                             "race_round",
                             "race_title",
                             "weather",
                             "ground_status",
                             "where_racecourse",
                             "total_horse_number",
                             "frame_number_first",
                             "horse_number_first",
                             "frame_number_second",
                             "horse_number_second",
                             "frame_number_third",
                             "horse_number_third",
                             "tansyo",
                             "hukusyo_first",
                             "hukusyo_second",
                             "hukusyo_third",
                             "wakuren",
                             "umaren",
                             "wide_1_2",
                             "wide_1_3",
                             "wide_2_3",
                             "umatan",
                             "renhuku3",
                             "rentan3",
                             "is_obstacle",
                             "ground_type",
                             "is_left_right_straight",
                             "distance",
                             "weather_rain",
                             "weather_snow",
                             "datetime"
                            ]]

merged_horse_df = pd.merge(horse_df, race_df_for_merge, on='race_id')

# %%
#datetimeをUnix時間に変換してint32に変換する
unix_time = merged_horse_df['datetime'].astype('int64')
unix_time_int32 = unix_time.astype('int32')

merged_horse_df['datetime'] = unix_time_int32

# %%
#エンコード
for column in ['race_title',
               'weather',
               'where_racecourse',
               'ground_type',
               'is_left_right_straight']:
    le = LabelEncoder()
    le.fit(merged_horse_df[column])
    merged_horse_df[column] = le.transform(merged_horse_df[column])

# %%
#使う特徴量の設定
id = {"race_id",
      "horse_id"
    }

feature = [
#horse_df
           "race_id",#後で抜く
           "horse_id",#後で抜く
#            "rank",#目的変数
    
    
           "frame_number",
           "horse_number",
           "sex_and_age",
           "burden_weight",
           "rider_id",
#            "goal_time",結果なので
#            "goal_time_dif",結果なので
#            "half_way_rank",結果なので
#            "last_time",結果なので
#            "odds",
#            "popular",
           "horse_weight",
           "tamer_id",
           "owner_id",
           "is_down",
           "is_senba",
           "is_mesu",
           "is_osu",
           "horse_weight_dif",
           "burden_weight_rate",
#            "avg_velocity",結果なので

#race_df           
             "race_round",
#              "race_title",タイトルはややこしいので
             "weather",
             "ground_status",
             "where_racecourse",
             "total_horse_number",
#              "frame_number_first",結果なので
#              "horse_number_first",
#              "frame_number_second",
#              "horse_number_second",
#              "frame_number_third",
#              "horse_number_third",
#              "tansyo",
#              "hukusyo_first",
#              "hukusyo_second",
#              "hukusyo_third",
#              "wakuren",
#              "umaren",
#              "wide_1_2",
#              "wide_1_3",
#              "wide_2_3",
#              "umatan",
#              "renhuku3",
#              "rentan3",
             "is_obstacle",
             "ground_type",
             "is_left_right_straight",
             "distance",
             "weather_rain",
             "weather_snow",
             "datetime"
            ]

target = ['rank']

X_id = merged_horse_df[feature]
y = merged_horse_df[target]

# %%
#スコア結果を入れるリスト
reports = []
auc_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
support_scores = []

#予測結果を入れるリスト
pred_df_list = []

def objective(trial):
    
# Optuna
    # ハイパーパラメータの探索範囲
    params = {
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 10, 100),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.1, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0),
        'verbose': -1
    }
    
    #LGBMRankerの設定
    ranker = LGBMRanker(**params)

# K-fold
    #kflodの設定
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)

    #kflodで学習用と検証用に分ける
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_id, y)):
        #id入りの学習データ
        X_train_id, X_val_id = X_id.iloc[train_idx], X_id.iloc[val_idx]
        
        #id抜きの学習データ
        X = X_id.drop(id, axis =1)
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        
        #検証データ
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

# Fit
        # train_basketsを計算
        train_baskets = X_train_id.groupby(["race_id"])["horse_id"].count().values

        # モデルの学習
        model = ranker.fit(X_train,
                           y_train,
                           group=train_baskets)

# Predict
        # モデルの予測
        y_pred = model.predict(X_val)

        #結果を入れるデータフレームを用意
        pred_df_fold = pd.DataFrame({
           "race_id": X_val_id['race_id'],
           "horse_id": X_val_id['horse_id'],
           "rank":y_val['rank'],
           "pred": y_pred
           })

        #そのデータフレームをリストに保存
        pred_df_list.append(pred_df_fold)

# Rank
    # 各foldの予測結果を結合してpred_dfを作成
    pred_df = pd.concat(pred_df_list, axis=0).reset_index(drop=True)

    #予測した結果をrace_idごとでグループ化し順位をつける
    pred_df['pred_rank'] = pred_df.groupby('race_id')['pred'].rank(method='min', ascending=False)

    #3位以内ならprizeを1にする
    pred_df['rank_prize'] = pred_df['rank'].apply(lambda x: 1 if x <= 3 else 0)
    pred_df['pred_rank_prize'] = pred_df['pred_rank'].apply(lambda x: 1 if x <= 3 else 0)

#Score
    #正確度を計算
    auc_score = metrics.accuracy_score(pred_df['rank_prize'], pred_df['pred_rank_prize'])
        
    #auc_scoresのリストに保存
    auc_scores.append(auc_score)
    
    #f1を計算            
    f1 = f1_score(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    
    #reportを計算
    report = metrics.classification_report(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    report_num = metrics.precision_recall_fscore_support(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    reports.append(report)

    #reportから情報をとる
    precision_scores.append(report_num[0])
    recall_scores.append(report_num[1])
    f1_scores.append(report_num[2])
    support_scores.append(report_num[3])
    
    return f1

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-03-13 17:57:37,668] A new study created in memory with name: no-name-9fc80322-3a12-4542-abb2-612c1efa4fb6
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6
colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777200705637682
# [LightGBM] [Warning] lambda_l1 is set=5.919957796305172, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.919957796305172
# [LightGBM] [Warning] bagging_fraction is set=0.9748026276472292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9748026276472292
# [LightGBM] [Warning] lambda_l2 is set=3.488137017130875, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.488137017130875
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.3777200705637682, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777200705637682
# [LightGBM] [Warning] lambda_l1 is set=5.919957796305172, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.919957796305172
# [LightGBM] [Warning] bagging_fraction is set=0.9748026276472292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9748026276472292
# [LightGBM] [Warning] lambda_l2 is set=3.488137017130875, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.488137017130875
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.3777200705637682, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777200705637682
# [LightGBM] [Warning] lambda_l1 is set=5.919957796305172, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.919957796305172
# [LightGBM] [Warning] bagging_fraction is set=0.9748026276472292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9748026276472292
# [LightGBM] [Warning] lambda_l2 is set=3.488137017130875, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.488137017130875
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.3777200705637682, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777200705637682
# [LightGBM] [Warning] lambda_l1 is set=5.919957796305172, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.919957796305172
# [LightGBM] [Warning] bagging_fraction is set=0.9748026276472292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9748026276472292
# [LightGBM] [Warning] lambda_l2 is set=3.488137017130875, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.488137017130875
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.3777200705637682, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777200705637682
# [LightGBM] [Warning] lambda_l1 is set=5.919957796305172, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.919957796305172
# [LightGBM] [Warning] bagging_fraction is set=0.9748026276472292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9748026276472292
# [LightGBM] [Warning] lambda_l2 is set=3.488137017130875, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.488137017130875
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2023-03-13 17:57:42,826] Trial 2 finished with value: 0.07916666666666666 and parameters: {'num_leaves': 28, 'learning_rate': 0.0469122125628086, 'feature_fraction': 0.3777200705637682, 'bagging_fraction': 0.9748026276472292, 'bagging_freq': 1, 'lambda_l1': 5.919957796305172, 'lambda_l2': 3.488137017130875}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.9388112034439117, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9388112034439117
# [LightGBM] [Warning] lambda_l1 is set=2.945277644578965, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.945277644578965
# [LightGBM] [Warning] bagging_fraction is set=0.32491379474039206, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32491379474039206
# [LightGBM] [Warning] lambda_l2 is set=7.127116501518182, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.127116501518182
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9388112034439117, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9388112034439117
# [LightGBM] [Warning] lambda_l1 is set=2.945277644578965, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.945277644578965
# [LightGBM] [Warning] bagging_fraction is set=0.32491379474039206, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32491379474039206
# [LightGBM] [Warning] lambda_l2 is set=7.127116501518182, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.127116501518182
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9388112034439117, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9388112034439117
# [LightGBM] [Warning] lambda_l1 is set=2.945277644578965, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.945277644578965
# [LightGBM] [Warning] bagging_fraction is set=0.32491379474039206, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32491379474039206
# [LightGBM] [Warning] lambda_l2 is set=7.127116501518182, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.127116501518182
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9388112034439117, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9388112034439117
# [LightGBM] [Warning] lambda_l1 is set=2.945277644578965, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.945277644578965
# [LightGBM] [Warning] bagging_fraction is set=0.32491379474039206, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32491379474039206
# [LightGBM] [Warning] lambda_l2 is set=7.127116501518182, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.127116501518182
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.9388112034439117, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.
colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15570769952451036
# [LightGBM] [Warning] lambda_l1 is set=1.3224675761484275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3224675761484275
# [LightGBM] [Warning] bagging_fraction is set=0.8932753704447995, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8932753704447995
# [LightGBM] [Warning] lambda_l2 is set=8.09564450620854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.09564450620854
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.15570769952451036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15570769952451036
# [LightGBM] [Warning] lambda_l1 is set=1.3224675761484275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3224675761484275
# [LightGBM] [Warning] bagging_fraction is set=0.8932753704447995, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8932753704447995
# [LightGBM] [Warning] lambda_l2 is set=8.09564450620854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.09564450620854
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.15570769952451036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15570769952451036
# [LightGBM] [Warning] lambda_l1 is set=1.3224675761484275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3224675761484275
# [LightGBM] [Warning] bagging_fraction is set=0.8932753704447995, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8932753704447995
# [LightGBM] [Warning] lambda_l2 is set=8.09564450620854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.09564450620854
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.15570769952451036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15570769952451036
# [LightGBM] [Warning] lambda_l1 is set=1.3224675761484275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3224675761484275
# [LightGBM] [Warning] bagging_fraction is set=0.8932753704447995, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8932753704447995
# [LightGBM] [Warning] lambda_l2 is set=8.09564450620854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.09564450620854
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.15570769952451036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15570769952451036
# [LightGBM] [Warning] lambda_l1 is set=1.3224675761484275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3224675761484275
# [LightGBM] [Warning] bagging_fraction is set=0.8932753704447995, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8932753704447995
# [LightGBM] [Warning] lambda_l2 is set=8.09564450620854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.09564450620854
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2023-03-13 17:57:51,819] Trial 7 finished with value: 0.03407407407407407 and parameters: {'num_leaves': 76, 'learning_rate': 0.022664709064958478, 'feature_fraction': 0.15570769952451036, 'bagging_fraction': 0.8932753704447995, 'bagging_freq': 1, 'lambda_l1': 1.3224675761484275, 'lambda_l2': 8.09564450620854}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.13186951342206982, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13186951342206982
# [LightGBM] [Warning] lambda_l1 is set=6.205635125042248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.205635125042248
# [LightGBM] [Warning] bagging_fraction is set=0.44298530619989906, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44298530619989906
# [LightGBM] [Warning] lambda_l2 is set=4.2732280429978555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2732280429978555
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.13186951342206982, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13186951342206982
# [LightGBM] [Warning] lambda_l1 is set=6.205635125042248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.205635125042248
# [LightGBM] [Warning] bagging_fraction is set=0.44298530619989906, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44298530619989906
# [LightGBM] [Warning] lambda_l2 is set=4.2732280429978555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2732280429978555
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.13186951342206982, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13186951342206982
# [LightGBM] [Warning] lambda_l1 is set=6.205635125042248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.205635125042248
# [LightGBM] [Warning] bagging_fraction is set=0.44298530619989906, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44298530619989906
# [LightGBM] [Warning] lambda_l2 is set=4.2732280429978555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2732280429978555
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.13186951342206982, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13186951342206982
# [LightGBM] [Warning] lambda_l1 is set=6.205635125042248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.205635125042248
# [LightGBM] [Warning] bagging_fraction is set=0.44298530619989906, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44298530619989906
# [LightGBM] [Warning] lambda_l2 is set=4.2732280429978555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2732280429978555
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.13186951342206982, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13186951342206982
# [LightGBM] [Warning] lambda_l1 is set=6.205635125042248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.205635125042248
# [LightGBM] [Warning] bagging_fraction is set=0.44298530619989906, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44298530619989906
# [LightGBM] [Warning] lambda_l2 is set=4.2732280429978555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2732280429978555
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [I 2023-03-13 17:57:53,436] Trial 8 finished with value: 0.029 and parameters: {'num_leaves': 75, 'learning_rate': 0.02092518216498481, 'feature_fraction': 0.13186951342206982, 'bagging_fraction': 0.44298530619989906, 'bagging_freq': 9, 'lambda_l1': 6.205635125042248, 'lambda_l2': 4.2732280429978555}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.8465154235607892, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8465154235607892
# [LightGBM] [Warning] lambda_l1 is set=4.212316966397245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.212316966397245
# [LightGBM] [Warning] bagging_fraction is set=0.6344814662526246, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6344814662526246
# [LightGBM] [Warning] lambda_l2 is set=6.716266923238898, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.716266923238898
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.8465154235607892, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8465154235607892
# [LightGBM] [Warning] lambda_l1 is set=4.212316966397245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.212316966397245
# [LightGBM] [Warning] bagging_fraction is set=0.6344814662526246, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6344814662526246
# [LightGBM] [Warning] lambda_l2 is set=6.716266923238898, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.716266923238898
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.8465154235607892, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8465154235607892
# [LightGBM] [Warning] lambda_l1 is set=4.212316966397245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.212316966397245
# [LightGBM] [Warning] bagging_fraction is set=0.6344814662526246, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6344814662526246
# [LightGBM] [Warning] lambda_l2 is set=6.716266923238898, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.716266923238898
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.8465154235607892, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8465154235607892
# [LightGBM] [Warning] lambda_l1 is set=4.212316966397245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.212316966397245
# [LightGBM] [Warning] bagging_fraction is set=0.6344814662526246, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6344814662526246
# [LightGBM] [Warning] lambda_l2 is set=6.716266923238898, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.716266923238898
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.8465154235607892, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8465154235607892
# [LightGBM] [Warning] lambda_l1 is set=4.212316966397245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.212316966397245
# [LightGBM] [Warning] bagging_fraction is set=0.6344814662526246, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6344814662526246
# [LightGBM] [Warning] lambda_l2 is set=6.716266923238898, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.716266923238898
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [I 2023-03-13 17:57:56,392] Trial 9 finished with value: 0.026161616161616164 and parameters: {'num_leaves': 93, 'learning_rate': 0.03705882684959626, 'feature_fraction': 0.8465154235607892, 'bagging_fraction': 0.6344814662526246, 'bagging_freq': 9, 'lambda_l1': 4.212316966397245, 'lambda_l2': 6.716266923238898}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.9659172073288458, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9659172073288458
# [LightGBM] [Warning] lambda_l1 is set=8.679629358771138, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.679629358771138
# [LightGBM] [Warning] bagging_fraction is set=0.11892894105569363, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11892894105569363
# [LightGBM] [Warning] lambda_l2 is set=9.994605772502448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.994605772502448
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.9659172073288458, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9659172073288458
# [LightGBM] [Warning] lambda_l1 is set=8.679629358771138, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.679629358771138
# [LightGBM] [Warning] bagging_fraction is set=0.11892894105569363, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11892894105569363
# [LightGBM] [Warning] lambda_l2 is set=9.994605772502448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.994605772502448
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.9659172073288458, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9659172073288458
# [LightGBM] [Warning] lambda_l1 is set=8.679629358771138, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.679629358771138
# [LightGBM] [Warning] bagging_fraction is set=0.11892894105569363, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11892894105569363
# [LightGBM] [Warning] lambda_l2 is set=9.994605772502448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.994605772502448
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.9659172073288458, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9659172073288458
# [LightGBM] [Warning] lambda_l1 is set=8.679629358771138, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.679629358771138
# [LightGBM] [Warning] bagging_fraction is set=0.11892894105569363, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11892894105569363
# [LightGBM] [Warning] lambda_l2 is set=9.994605772502448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.994605772502448
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.9659172073288458, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9659172073288458
# [LightGBM] [Warning] lambda_l1 is set=8.679629358771138, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.679629358771138
# [LightGBM] [Warning] bagging_fraction is set=0.11892894105569363, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11892894105569363
# [LightGBM] [Warning] lambda_l2 is set=9.994605772502448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.994605772502448
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2023-03-13 17:57:57,954] Trial 10 finished with value: 0.024814814814814814 and parameters: {'num_leaves': 73, 'learning_rate': 0.0005267867161217951, 'feature_fraction': 0.9659172073288458, 'bagging_fraction': 0.11892894105569363, 'bagging_freq': 3, 'lambda_l1': 8.679629358771138, 'lambda_l2': 9.994605772502448}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.6768706810178398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6768706810178398
# [LightGBM] [Warning] lambda_l1 is set=0.003047753728758984, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.003047753728758984
# [LightGBM] [Warning] bagging_fraction is set=0.10579319634379251, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10579319634379251
# [LightGBM] [Warning] lambda_l2 is set=0.18973065842096037, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18973065842096037
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6768706810178398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6768706810178398
# [LightGBM] [Warning] lambda_l1 is set=0.003047753728758984, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.003047753728758984
# [LightGBM] [Warning] bagging_fraction is set=0.10579319634379251, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10579319634379251
# [LightGBM] [Warning] lambda_l2 is set=0.18973065842096037, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18973065842096037
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6768706810178398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6768706810178398
# [LightGBM] [Warning] lambda_l1 is set=0.003047753728758984, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.003047753728758984
# [LightGBM] [Warning] bagging_fraction is set=0.10579319634379251, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10579319634379251
# [LightGBM] [Warning] lambda_l2 is set=0.18973065842096037, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18973065842096037
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6768706810178398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6768706810178398
# [LightGBM] [Warning] lambda_l1 is set=0.003047753728758984, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.003047753728758984
# [LightGBM] [Warning] bagging_fraction is set=0.10579319634379251, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10579319634379251
# [LightGBM] [Warning] lambda_l2 is set=0.18973065842096037, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18973065842096037
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6768706810178398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6768706810178398
# [LightGBM] [Warning] lambda_l1 is set=0.003047753728758984, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.003047753728758984
# [LightGBM] [Warning] bagging_fraction is set=0.10579319634379251, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10579319634379251
# [LightGBM] [Warning] lambda_l2 is set=0.18973065842096037, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18973065842096037
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [I 2023-03-13 17:57:59,676] Trial 11 finished with value: 0.022222222222222223 and parameters: {'num_leaves': 97, 'learning_rate': 0.07247883025508506, 'feature_fraction': 0.6768706810178398, 'bagging_fraction': 0.10579319634379251, 'bagging_freq': 6, 'lambda_l1': 0.003047753728758984, 'lambda_l2': 0.18973065842096037}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.534633121934381, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.534633121934381
# [LightGBM] [Warning] lambda_l1 is set=4.330496450253434, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.330496450253434
# [LightGBM] [Warning] bagging_fraction is set=0.41439374263607587, subsample=1.0 will be ignored. Current value: bagging_fraction=0.41439374263607587
# [LightGBM] [Warning] lambda_l2 is set=5.462091499815542, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.462091499815542
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.534633121934381, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.534633121934381
# [LightGBM] [Warning] lambda_l1 is set=4.330496450253434, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.330496450253434
# [LightGBM] [Warning] bagging_fraction is set=0.41439374263607587, subsample=1.0 will be ignored. Current value: bagging_fraction=0.41439374263607587
# [LightGBM] [Warning] lambda_l2 is set=5.462091499815542, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.462091499815542
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.534633121934381, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.534633121934381
# [LightGBM] [Warning] lambda_l1 is set=4.330496450253434, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.330496450253434
# [LightGBM] [Warning] bagging_fraction is set=0.41439374263607587, subsample=1.0 will be ignored. Current value: bagging_fraction=0.41439374263607587
# [LightGBM] [Warning] lambda_l2 is set=5.462091499815542, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.462091499815542
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.534633121934381, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.534633121934381
# [LightGBM] [Warning] lambda_l1 is set=4.330496450253434, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.330496450253434
# [LightGBM] [Warning] bagging_fraction is set=0.41439374263607587, subsample=1.0 will be ignored. Current value: bagging_fraction=0.41439374263607587
# [LightGBM] [Warning] lambda_l2 is set=5.462091499815542, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.462091499815542
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.534633121934381, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.534633121934381
# [LightGBM] [Warning] lambda_l1 is set=4.330496450253434, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.330496450253434
# ...
# [LightGBM] [Warning] feature_fraction is set=0.8443927637560662, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8443927637560662
# [LightGBM] [Warning] lambda_l1 is set=2.387404449502358, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.387404449502358
# [LightGBM] [Warning] bagging_fraction is set=0.3659715494246661, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3659715494246661
# [LightGBM] [Warning] lambda_l2 is set=6.832599834628058, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.832599834628058
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [I 2023-03-13 18:03:25,430] Trial 95 finished with value: 0.003069873997709049 and parameters: {'num_leaves': 51, 'learning_rate': 0.0167975893411732, 'feature_fraction': 0.8443927637560662, 'bagging_fraction': 0.3659715494246661, 'bagging_freq': 10, 'lambda_l1': 2.387404449502358, 'lambda_l2': 6.832599834628058}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.7668413886919108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7668413886919108
# [LightGBM] [Warning] lambda_l1 is set=5.526050008089898, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.526050008089898
# [LightGBM] [Warning] bagging_fraction is set=0.10845438084282899, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10845438084282899
# [LightGBM] [Warning] lambda_l2 is set=7.0785167587591555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.0785167587591555
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.7668413886919108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7668413886919108
# [LightGBM] [Warning] lambda_l1 is set=5.526050008089898, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.526050008089898
# [LightGBM] [Warning] bagging_fraction is set=0.10845438084282899, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10845438084282899
# [LightGBM] [Warning] lambda_l2 is set=7.0785167587591555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.0785167587591555
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.7668413886919108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7668413886919108
# [LightGBM] [Warning] lambda_l1 is set=5.526050008089898, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.526050008089898
# [LightGBM] [Warning] bagging_fraction is set=0.10845438084282899, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10845438084282899
# [LightGBM] [Warning] lambda_l2 is set=7.0785167587591555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.0785167587591555
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.7668413886919108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7668413886919108
# [LightGBM] [Warning] lambda_l1 is set=5.526050008089898, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.526050008089898
# [LightGBM] [Warning] bagging_fraction is set=0.10845438084282899, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10845438084282899
# [LightGBM] [Warning] lambda_l2 is set=7.0785167587591555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.0785167587591555
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.7668413886919108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7668413886919108
# [LightGBM] [Warning] lambda_l1 is set=5.526050008089898, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.526050008089898
# [LightGBM] [Warning] bagging_fraction is set=0.10845438084282899, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10845438084282899
# [LightGBM] [Warning] lambda_l2 is set=7.0785167587591555, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.0785167587591555
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2023-03-13 18:03:30,749] Trial 96 finished with value: 0.003038548752834468 and parameters: {'num_leaves': 30, 'learning_rate': 0.024200489577466844, 'feature_fraction': 0.7668413886919108, 'bagging_fraction': 0.10845438084282899, 'bagging_freq': 1, 'lambda_l1': 5.526050008089898, 'lambda_l2': 7.0785167587591555}. Best is trial 0 with value: 0.1638888888888889.
# [LightGBM] [Warning] feature_fraction is set=0.6155617423614201, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6155617423614201
# [LightGBM] [Warning] lambda_l1 is set=2.8489780320644282, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8489780320644282
# [LightGBM] [Warning] bagging_fraction is set=0.38447526554758227, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38447526554758227
# [LightGBM] [Warning] lambda_l2 is set=4.941339982259573, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.941339982259573
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6155617423614201, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6155617423614201
# [LightGBM] [Warning] lambda_l1 is set=2.8489780320644282, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8489780320644282
# [LightGBM] [Warning] bagging_fraction is set=0.38447526554758227, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38447526554758227
# [LightGBM] [Warning] lambda_l2 is set=4.941339982259573, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.941339982259573
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6155617423614201, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6155617423614201
# [LightGBM] [Warning] lambda_l1 is set=2.8489780320644282, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8489780320644282
# [LightGBM] [Warning] bagging_fraction is set=0.38447526554758227, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38447526554758227
# [LightGBM] [Warning] lambda_l2 is set=4.941339982259573, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.941339982259573
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6155617423614201, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6155617423614201
# [LightGBM] [Warning] lambda_l1 is set=2.8489780320644282, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8489780320644282
# [LightGBM] [Warning] bagging_fraction is set=0.38447526554758227, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38447526554758227
# [LightGBM] [Warning] lambda_l2 is set=4.941339982259573, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.941339982259573
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.6155617423614201, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6155617423614201
# [LightGBM] [Warning] lambda_l1 is set=2.8489780320644282, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.8489780320644282
# [LightGBM] [Warning] bagging_fraction is set=0.38447526554758227, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38447526554758227
# [LightGBM] [Warning] lambda_l2 is set=4.941339982259573, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.941339982259573
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
#
# 97              0.085309                 98  COMPLETE
# 98              0.083554                 12  COMPLETE
# 99              0.096482                 15  COMPLETE
#
# [100 rows x 13 columns]

# %%
#各ランダムステートの正確度平均と標準偏差を出力
avg_auc_score = np.mean(auc_scores, axis=0)
std_score = np.std(auc_scores, axis=0)

# 平均と重み付き平均を計算する
precision_avg = np.mean(precision_scores, axis=0)
recall_avg = np.mean(recall_scores, axis=0)
f1_avg = np.mean(f1_scores, axis=0)
support_sum = np.sum(support_scores, axis=0)

# precision_weighted = np.average(precision_avg, weights=support_sum)
# recall_weighted = np.average(recall_avg, weights=support_sum)
# f1_weighted = np.average(f1_avg, weights=support_sum)

# %%
print(f"Std: {std_score:.4f}")
print(f"Average AUC score: {avg_auc_score:.4f}")
print(f"Average PRE score 0: {precision_avg[0]:.4f}"+f"   1: {precision_avg[1]:.4f}")
print(f"Average REC score 0: {recall_avg[0]:.4f}"+f"   1: {recall_avg[1]:.4f}")
print(f"Average F1  score 0: {f1_avg[0]:.4f}"+f"   1: {f1_avg[1]:.4f}")
# Out:
# Std: 0.0168
# Average AUC score: 0.7790
# Average PRE score 0: 0.7860   1: 0.1502
# Average REC score 0: 0.9881   1: 0.0081
# Average F1  score 0: 0.8754   1: 0.0130

# %%
print(reports[0])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      6637
#            1       0.16      0.16      0.16      1800
#
#     accuracy                           0.64      8437
#    macro avg       0.47      0.47      0.47      8437
# weighted avg       0.64      0.64      0.64      8437

# %%
#Optunaによる、ベストパラメータの取得
best_params = study.best_params

# %%
#結果を入れるリスト
reports = []
auc_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
support_scores = []
#予測結果を入れるリスト
pred_df_list = []

#ランダムステートを変更し、kfoldを繰り返す
for random_state in range(5):
    
    #kflodの設定
    kfold = KFold(n_splits=5, shuffle=True, random_state=random_state)
    
    #kflodで学習用と検証用に分ける
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_id, y)):
        X_train_id, X_val_id = X_id.iloc[train_idx], X_id.iloc[val_idx]
        
        X = X_id.drop(id, axis =1)
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # ここでtrain_basketsを計算する
        train_baskets = X_train_id.groupby(["race_id"])["horse_id"].count().values
        
        best_ranker = LGBMRanker(**best_params)

        # モデルの学習
        model = best_ranker.fit(X_train,
                           y_train,
                           group=train_baskets)

        # モデルの予測
        y_pred = model.predict(X_val)

        #結果を入れるデータフレームを用意
        pred_df_fold = pd.DataFrame({
           "race_id": X_val_id['race_id'],
           "horse_id": X_val_id['horse_id'],
           "rank":y_val['rank'],
           "pred": y_pred
           })
        
        #そのデータフレームをリストに保存
        pred_df_list.append(pred_df_fold)

    # 各foldの予測結果を結合してpred_dfを作成
    pred_df = pd.concat(pred_df_list, axis=0).reset_index(drop=True)
    
    #予測した結果をrace_idごとでグループ化し順位をつける
    pred_df['pred_rank'] = pred_df.groupby('race_id')['pred'].rank(method='min', ascending=False)
    
    #3位以内ならprizeを1にする
    pred_df['rank_prize'] = pred_df['rank'].apply(lambda x: 1 if x <= 3 else 0)
    pred_df['pred_rank_prize'] = pred_df['pred_rank'].apply(lambda x: 1 if x <= 3 else 0)
    
    #正確度を計算
    auc_score = metrics.accuracy_score(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    report = metrics.classification_report(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    report_num = metrics.precision_recall_fscore_support(pred_df['rank_prize'], pred_df['pred_rank_prize'])
    #auc_scoresのリストに保存
    auc_scores.append(auc_score)
    
    reports.append(report)
    
    precision_scores.append(report_num[0])
    recall_scores.append(report_num[1])
    f1_scores.append(report_num[2])
    support_scores.append(report_num[3])
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.
, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.9489874719416007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9489874719416007
# [LightGBM] [Warning] lambda_l1 is set=6.545008548099908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.545008548099908
# [LightGBM] [Warning] bagging_fraction is set=0.14534210109086637, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14534210109086637
# [LightGBM] [Warning] lambda_l2 is set=9.665103167811342, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.665103167811342
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1

# %%
#各ランダムステートの正確度平均と標準偏差を出力
avg_auc_score = np.mean(auc_scores, axis=0)
std_score = np.std(auc_scores, axis=0)

# 平均と重み付き平均を計算する
precision_avg = np.mean(precision_scores, axis=0)
recall_avg = np.mean(recall_scores, axis=0)
f1_avg = np.mean(f1_scores, axis=0)
support_sum = np.sum(support_scores, axis=0)

# %%
print(f"Std: {std_score:.4f}")
print(f"Average AUC score: {avg_auc_score:.4f}")
print(f"Average PRE score 0: {precision_avg[0]:.4f}"+f"   1: {precision_avg[1]:.4f}")
print(f"Average REC score 0: {recall_avg[0]:.4f}"+f"   1: {recall_avg[1]:.4f}")
print(f"Average F1  score 0: {f1_avg[0]:.4f}"+f"   1: {f1_avg[1]:.4f}")
# Out:
# Std: 0.0406
# Average AUC score: 0.7190
# Average PRE score 0: 0.7799   1: 0.1468
# Average REC score 0: 0.8951   1: 0.0698
# Average F1  score 0: 0.8325   1: 0.0873

# %%
#特徴量の重要度
for i in model.feature_importances_.argsort()[::-1]:
    print(feature[i], model.feature_importances_[i]/model.feature_importances_.sum())
# Out:
# weather_rain 0.1231841952353283
# sex_and_age 0.11969785008715862
# horse_weight 0.1167925624636839
# rider_id 0.11330621731551424
# is_osu 0.0894828588030215
# is_mesu 0.06798373038930854
# burden_weight 0.06333527019174898
# horse_id 0.05810575246949448
# horse_weight_dif 0.0505520046484602
# ground_type 0.03834979662986636
# ground_status 0.037187681580476466
# horse_number 0.03021499128413713
# race_id 0.023823358512492735
# frame_number 0.02149912841371296
# weather 0.013945380592678676
# race_round 0.008715862870424172
# burden_weight_rate 0.007553747821034283
# is_senba 0.004648460197559558
# is_obstacle 0.004648460197559558
# total_horse_number 0.002905287623474724
# is_down 0.002324230098779779
# owner_id 0.0017431725740848344
# is_left_right_straight 0.0
# tamer_id 0.0
# distance 0.0
# where_racecourse 0.0

# %%
#混同行列
cm = confusion_matrix(pred_df['rank_prize'], pred_df['pred_rank_prize'])
sns.heatmap(cm, annot=True, cmap='Blues',fmt=".0f")
# Out:
# <AxesSubplot:>
